# %%
import pandas as pd
import numpy as np

# %%
# 불러오기
data=pd.read_csv(r'C:\Users\LG\Desktop\교수님\과제\과제1-데이터예시(seoul.csv).csv')
data
# Out:
#            사용일자       노선명        역명  승차총승객수  하차총승객수  승하차객수
# 0      20240701  9호선2~3단계      석촌고분    7665    7414  15079
# 1      20240701       중앙선        도농   12178   10957  23135
# 2      20240701       중앙선        구리   14053   14085  28138
# 3      20240701       4호선        길음   22687   22215  44902
# 4      20240701       분당선        복정       1       0      1
# ...         ...       ...       ...     ...     ...    ...
# 19098  20240731       7호선        신풍   11494   10664  22158
# 19099  20240731       7호선  대림(구로구청)    9328    9366  18694
# 19100  20240731       7호선       남구로   15284   16072  31356
# 19101  20240731       7호선   가산디지털단지   47493   47452  94945
# 19102  20240731       7호선        철산   21851   22156  44007
#
# [19103 rows x 6 columns]

# %%
df= pd.DataFrame(data)
df
# Out:
#            사용일자       노선명        역명  승차총승객수  하차총승객수  승하차객수
# 0      20240701  9호선2~3단계      석촌고분    7665    7414  15079
# 1      20240701       중앙선        도농   12178   10957  23135
# 2      20240701       중앙선        구리   14053   14085  28138
# 3      20240701       4호선        길음   22687   22215  44902
# 4      20240701       분당선        복정       1       0      1
# ...         ...       ...       ...     ...     ...    ...
# 19098  20240731       7호선        신풍   11494   10664  22158
# 19099  20240731       7호선  대림(구로구청)    9328    9366  18694
# 19100  20240731       7호선       남구로   15284   16072  31356
# 19101  20240731       7호선   가산디지털단지   47493   47452  94945
# 19102  20240731       7호선        철산   21851   22156  44007
#
# [19103 rows x 6 columns]

# %%
df.shape
# Out:
# (19103, 6)

# %%
# 지하철 역별 평균 이용객수
# average_passengers = df.groupby('역명')['승하차객수'].mean().reset_index()

# # 결과 출력
# print(average_passengers)



# a= df.olc[df['승하차승']]

count=df.shape[0]
count
df_total_count_people = df['승하차객수']



stations =set()
print(stations)
# total_count=df['승하차객수']
# total_count
# Out:
# set()

# %%
for i in range(0,count):
    stations.add(df.iloc[i]['역명'])

# %%
dict_count_of_people_on_station =  dict()
for station in stations :
    dict_count_of_people_on_station[station] = 0
print(dict_count_of_people_on_station)
# Out:
# {'범계': 0, '백양리': 0, '교대(법원.검찰청)': 0, '오산': 0, '고덕': 0, '까치산': 0, '건대입구': 0, '퇴계원': 0, '야탑': 0, '지평': 0, '연수': 0, '오이도': 0, '동대입구': 0, '오빈': 0, '마포': 0, '논현': 0, '미아(서울사이버대학)': 0, '응암': 0, '온수(성공회대입구)': 0, '제기동': 0, '광명': 0, '길동': 0, '일원': 0, '석촌': 0, '철산': 0, '도봉': 0, '삼양사거리': 0, '신내': 0, '옥수': 0, '덕정': 0, '선정릉': 0, '소래포구': 0, '굴봉산': 0, '외대앞': 0, '봉명': 0, '녹천': 0, '임진강': 0, '한티': 0, '평택지제': 0, '송정': 0, '인천공항1터미널': 0, '솔샘': 0, '신길': 0, '백마': 0, '구룡': 0, '장암': 0, '숙대입구(갈월)': 0, '굽은다리(강동구민회관앞)': 0, '세종대왕릉': 0, '노들': 0, '신림': 0, '오리': 0, '춘천': 0, '개화산': 0, '방이': 0, '상왕십리': 0, '신논현': 0, '일산': 0, '내방': 0, '중계': 0, '금곡': 0, '마천': 0, '매봉': 0, '석수': 0, '신포': 0, '신촌': 0, '회현(남대문시장)': 0, '남성': 0, '서울대벤처타운': 0, '태평': 0, '쌍문': 0, '남춘천': 0, '세마': 0, '오류동': 0, '개봉': 0, '양정': 0, '경기광주': 0, '도림천': 0, '한양대': 0, '올림픽공원(한국체대)': 0, '사가정': 0, '마들': 0, '청명': 0, '신답': 0, '새절(신사)': 0, '성남': 0, '대공원': 0, '지행': 0, '돌곶이': 0, '독바위': 0, '삼송': 0, '공항시장': 0, '단대오거리': 0, '주엽': 0, '정릉': 0, '한성대입구(삼선교)': 0, '상월곡(한국과학기
# ...

# %%
#각 지하철 역별 이용객수의 표준 편차

# %%
# 가장 많은 이용객이 있는 역의 이용객수

# %%
#가장 적은 이용객이 있는 역의 이용객 수
# shape

# %%
# for i in range(0,count):
#     stations.add(df.iloc[i]['역명'])


# dict_count =dict()
# for station in stations:
#     dict_count[stations] =0
# print(dict_count)

# %%
for i in range(0,count):
    current = df. iloc[i]
    station = current['역명']
    dict_count_of_people_on_station[station] = dict_count_of_people_on_station[station]+current['승하차객수']
print(dict_count_of_people_on_station)
# Out:
# {'범계': 1629136, '백양리': 5109, '교대(법원.검찰청)': 2796443, '오산': 612254, '고덕': 638033, '까치산': 1624142, '건대입구': 3014756, '퇴계원': 200673, '야탑': 1546073, '지평': 3939, '연수': 290622, '오이도': 471927, '동대입구': 606352, '오빈': 19221, '마포': 874864, '논현': 1104923, '미아(서울사이버대학)': 891912, '응암': 1042704, '온수(성공회대입구)': 899190, '제기동': 983967, '광명': 219362, '길동': 507525, '일원': 633844, '석촌': 1081147, '철산': 1285099, '도봉': 352380, '삼양사거리': 158747, '신내': 152742, '옥수': 540730, '덕정': 335264, '선정릉': 1054916, '소래포구': 276432, '굴봉산': 8799, '외대앞': 508826, '봉명': 80717, '녹천': 248659, '임진강': 1587, '한티': 1016312, '평택지제': 253022, '송정': 373308, '인천공항1터미널': 925825, '솔샘': 342487, '신길': 774714, '백마': 430014, '구룡': 215043, '장암': 124144, '숙대입구(갈월)': 847015, '굽은다리(강동구민회관앞)': 591216, '세종대왕릉': 21596, '노들': 271425, '신림': 3398688, '오리': 632876, '춘천': 79770, '개화산': 353289, '방이': 448525, '상왕십리': 862692, '신논현': 1912312, '일산': 629894, '내방': 863230, '중계': 831225, '금곡': 84073, '마천': 425619, '매봉': 736023, '석수': 484159, '신포': 112189, '신촌': 236878
# ...

# %%
df ['승하차객수'].max
# Out:
# <bound method Series.max of 0        15079
# 1        23135
# 2        28138
# 3        44902
# 4            1
#          ...
# 19098    22158
# 19099    18694
# 19100    31356
# 19101    94945
# 19102    44007
# Name: 승하차객수, Length: 19103, dtype: int64>
