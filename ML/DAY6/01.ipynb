# %% [markdown]
# 데이터 탐색적분석
# -전처리 : 모든것을 수치와 -> 범주형 : 인코딩 [소분류 .>> 대분류 ]
# 지도/비지도/강화-->    선형 모델     -  피쳐와 타겟의 관계 선형관계
# 학습알고리즘-->                     - 정규분포 기반
#                                    - 선형식 :
#                                    -coefficent 또는 Weight
#                                    : 학습을 통해서 다양한 피쳐들의 영향정도를 정확하게 반영하기 위해 사용
#
# 파라미터
# -모델 파리미터
# : fit() 학습진행 후 설정되는 파라미터
# : 모델. 파라미터명_
#
# 하이퍼파라미터
# : 모델 인스턴스 생성시 매개변수
# : 모델 인스턴스 생성할때 개발자가 값을 설정
# : 모델 성능에 따라 영향 미침
# : (예) 규제강도alpha, K 개수 , 학습 횟수 max_iter
#       규제강도C(alpha역수)
#
# 튜닝
# : 모델 성능을 높이는 작업
#  즉, 모델의 하이퍼파라미터의 값을 조절해서 성능을 올리기
#
# 좋은 모델
# - 일반화가 잘된모델
# - 모델 복잡도 -> 간소한 모델 (피쳐 수가 간소한 것)
