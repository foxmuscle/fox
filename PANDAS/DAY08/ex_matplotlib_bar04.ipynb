# %% [markdown]
# #### 막대그래프 활용

# %%
# [1-1] 모듈로딩
import pandas as pd                    # 데이터 분석용 모듈
import matplotlib.pyplot as plt        # 데이터 시각화용 모듈
import numpy as np

# %%
# [3] 팽귄품족 시각화
# - 품종에 따른 성별 비교
fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    # bottom 매개변수 :누적
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count
# 막대 그래프 내에 라벨추가
    ax.bar_label(p, label_type='center')
ax.set(title='Number of penguins by sex',xlabel= 'penguins',ylabel='count')
# ax.set_title('Number of penguins by sex')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 fig, ax = plt.subplots()
#       4 bottom = np.zeros(3)
# ----> 6 for sex, sex_count in sex_counts.items():
#       7     # bottom 매개변수 :누적
#       8     p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
#       9     bottom += sex_count
#
# NameError: name 'sex_counts' is not defined

# %% [markdown]
# #### 다중 막대 그래프

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np
#x 축 데이터
species = ("Adelie", "Chinstrap", "Gentoo")
# y 축데이터
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}
# 그래프에 나타낼 X 축 위치 값 , 막대 그래프 너비, 다중 막대그래프 간격 값
x = np.arange(len(species))  # (0,3,1)
width = 0.25                  # the width of the bars
multiplier = 0               # 막대그래프 간격

# %%
# 품종별 특징 비교 다중그래프
fig, ax = plt.subplots(layout='constrained')
# 막대그리기
for attribute, measurement in penguin_means.items():
    offset = width * multiplier          #offset 떨어진 간격
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3) #그래프 padding
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()
