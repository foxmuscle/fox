# %% [markdown]
# ### RandomForest 로 중량값 회귀 예측
# - 데이터셋: Train: 1차 데이터셋 0 전처리 w/ RandomForest + Test: 2차 데이터셋
# - 타겟: scale_pv
# - 피쳐: s_temp, c_temp, n_temp, k_rpm
# - 학습: 회귀 >> 중량값 예측
# - 알고리즘: RandomForest
# - 프레임워크: scikit-learn

# %%
# 데이터 로드 관련 모듈 로딩 -------------------------------
import pandas as pd
import numpy as np

# 시각화 관련 모듈 ----------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# 모델 관련 모듈 로딩 --------------------------------------
from lightgbm import LGBMRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn import datasets
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 로드
PATH = r'C:\Users\KDP-43\Desktop\기업프로젝트\data\second_refill\total_refill_RF_1126.csv'

rawDF = pd.read_csv(PATH)
rawDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232075 entries, 0 to 232074
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   c_temp_pv  232075 non-null  float64
#  1   k_rpm_pv   232075 non-null  int64
#  2   n_temp_pv  232075 non-null  float64
#  3   scale_pv   232075 non-null  float64
#  4   s_temp_pv  232075 non-null  float64
# dtypes: float64(4), int64(1)
# memory usage: 8.9 MB

# %%
# 전처리 확인
print("중량 0 개수:", sum(rawDF['scale_pv'].isin([0])))
print("rpm 40이하 개수:", sum(rawDF['k_rpm_pv']<=40))
# Out:
# 중량 0 개수: 0
# rpm 40이하 개수: 0

# %%
# Train, Val, Test 분리

y_target = rawDF['scale_pv']
X_feature = rawDF.drop(['scale_pv'], axis=1, inplace=False)

X_train, X_test, y_train, y_test = train_test_split(X_feature, y_target, 
                                                    test_size=0.2,
                                                    random_state=77)


# 크기 확인
print(f"X_train: {X_train.shape} {X_train.ndim}D")
print(f"y_train: {y_train.shape} {y_train.ndim}D")

print("="*30)
print(f"X_test: {X_test.shape} {X_test.ndim}D")
print(f"y_test: {y_test.shape} {y_test.ndim}D")
# Out:
# X_train: (185660, 4) 2D
# y_train: (185660,) 1D
# ...
# X_test: (46415, 4) 2D
# y_test: (46415,) 1D

# %%
# Randomforest 인스턴스 생성
model = RandomForestRegressor(random_state=77)

# 모델 학습
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=77)

# %%
# 모델 예측
y_pred = model.predict(X_train)

# 성능
mae = mean_absolute_error(y_pred=y_pred, y_true=y_train)
mape = mean_absolute_percentage_error(y_pred=y_pred, y_true=y_train)
r2 = r2_score(y_pred=y_pred, y_true=y_train)

print(f"mae = {mae}")
print(f"mape = {mape*100}%")
print(f"r2 ={r2}")
# Out:
# mae = 0.0024015101206269836
# mape = 0.07899249135317718%
# r2 =0.9423989964705404

# %%
# 모델 예측
y_pred = model.predict(X_test)

# 성능
mae = mean_absolute_error(y_pred=y_pred, y_true=y_test)
mape = mean_absolute_percentage_error(y_pred=y_pred, y_true=y_test)
r2 = r2_score(y_pred=y_pred, y_true=y_test)

print(f"mae = {mae}")
print(f"mape = {mape*100}%")
print(f"r2 ={r2}")
# Out:
# mae = 0.004748661895818447
# mape = 0.15613326431358995%
# r2 =0.8063757719537847

# %%
# 예측

tmp_list = [71.5,163,67.8,66.4]
tmp_test = pd.DataFrame(data = [tmp_list], columns=X_test.columns.tolist())

y_pred = model.predict(tmp_test)
print(y_pred)
# Out:
# [3.2182501]

# %%
# 모델 저장
import joblib

joblib.dump(model, './model/scale_RF_1202_r2_0.806.pkl')
# Out:
# ['./model/scale_RF_1202_r2_0.806.pkl']
